# %%
import pandas as pd

# %%
df = pd.read_csv("Absenteeism_data.csv")
df
# Out:
#      ID  Reason for Absence        Date  Transportation Expense  \
# 0    11                  26  07/07/2015                     289
# 1    36                   0  14/07/2015                     118
# 2     3                  23  15/07/2015                     179
# 3     7                   7  16/07/2015                     279
# 4    11                  23  23/07/2015                     289
# ..   ..                 ...         ...                     ...
# 695  17                  10  23/05/2018                     179
# 696  28                   6  23/05/2018                     225
# 697  18                  10  24/05/2018                     330
# 698  25                  23  24/05/2018                     235
# 699  15                  28  31/05/2018                     291
#
#      Distance to Work  Age  Daily Work Load Average  Body Mass Index  \
# 0                  36   33                  239.554               30
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ID                         700 non-null    int64
#  1   Reason for Absence         700 non-null    int64
#  2   Date                       700 non-null    object
#  3   Transportation Expense     700 non-null    int64
#  4   Distance to Work           700 non-null    int64
#  5   Age                        700 non-null    int64
#  6   Daily Work Load Average    700 non-null    float64
#  7   Body Mass Index            700 non-null    int64
#  8   Education                  700 non-null    int64
#  9   Children                   700 non-null    int64
#  10  Pets                       700 non-null    int64
#  11  Absenteeism Time in Hours  700 non-null    int64
# dtypes: float64(1), int64(10), object(1)
# memory usage: 65.8+ KB

# %%
df = df.drop(columns=['ID'])#droping ID col
df
# Out:
#      Reason for Absence        Date  Transportation Expense  Distance to Work  \
# 0                    26  07/07/2015                     289                36
# 1                     0  14/07/2015                     118                13
# 2                    23  15/07/2015                     179                51
# 3                     7  16/07/2015                     279                 5
# 4                    23  23/07/2015                     289                36
# ..                  ...         ...                     ...               ...
# 695                  10  23/05/2018                     179                22
# 696                   6  23/05/2018                     225                26
# 697                  10  24/05/2018                     330                16
# 698                  23  24/05/2018                     235                16
# 699                  28  31/05/2018                     291                31
#
# ...

# %%
df = df.drop(columns=["Age"])#droping Age col
df
# Out:
#      Reason for Absence        Date  Transportation Expense  Distance to Work  \
# 0                    26  07/07/2015                     289                36
# 1                     0  14/07/2015                     118                13
# 2                    23  15/07/2015                     179                51
# 3                     7  16/07/2015                     279                 5
# 4                    23  23/07/2015                     289                36
# ..                  ...         ...                     ...               ...
# 695                  10  23/05/2018                     179                22
# 696                   6  23/05/2018                     225                26
# 697                  10  24/05/2018                     330                16
# 698                  23  24/05/2018                     235                16
# 699                  28  31/05/2018                     291                31
#
# ...

# %%
df.sort_values(by='Reason for Absence')#arange the values from low to high
# Out:
#      Reason for Absence        Date  Transportation Expense  Distance to Work  \
# 530                   0  29/10/2017                     225                26
# 312                   0  27/10/2016                     291                31
# 311                   0  27/10/2016                     260                50
# 688                   0  15/05/2018                     118                13
# 690                   0  16/05/2018                     378                49
# ..                  ...         ...                     ...               ...
# 355                  28  19/12/2016                     157                27
# 351                  28  23/12/2016                     179                51
# 347                  28  16/12/2016                     179                51
# 344                  28  09/12/2016                     260                50
# 699                  28  31/05/2018                     291                31
#
# ...

# %%
df.sort_values(by='Reason for Absence', ascending=False)#arange the values from high to low
# Out:
#      Reason for Absence        Date  Transportation Expense  Distance to Work  \
# 699                  28  31/05/2018                     291                31
# 408                  28  31/03/2017                     179                51
# 106                  28  10/12/2015                     225                26
# 107                  28  11/12/2015                     260                50
# 421                  28  28/04/2017                     300                26
# ..                  ...         ...                     ...               ...
# 405                   0  30/03/2017                     235                11
# 406                   0  30/03/2017                     246                25
# 214                   0  18/05/2016                     330                16
# 313                   0  27/10/2016                     157                27
# 203                   0  04/04/2016                     235                29
#
# ...

# %%
df = pd.DataFrame(df)#finding the data type of the remaining col
df
# Out:
#      Reason for Absence        Date  Transportation Expense  Distance to Work  \
# 0                    26  07/07/2015                     289                36
# 1                     0  14/07/2015                     118                13
# 2                    23  15/07/2015                     179                51
# 3                     7  16/07/2015                     279                 5
# 4                    23  23/07/2015                     289                36
# ..                  ...         ...                     ...               ...
# 695                  10  23/05/2018                     179                22
# 696                   6  23/05/2018                     225                26
# 697                  10  24/05/2018                     330                16
# 698                  23  24/05/2018                     235                16
# 699                  28  31/05/2018                     291                31
#
# ...

# %%
#creating a line graph to show the relationship between the col
df.plot('Reason for Absence','Absenteeism Time in Hours')
# Out:
# <AxesSubplot:xlabel='Reason for Absence'>

# %%
df.plot(x="Distance to Work", y="Absenteeism Time in Hours")
plt.show()

# %%
'''Importing pandas is the first step and then read the csv file.
droping the ID and Age columns and saved back to "df" 
and after that storing "reason for absence "to ascending and desending order of the column
then finding the data types of thr remaining columns
after that creating a line graph to show the relations of two columns
and suitable graph.'''
